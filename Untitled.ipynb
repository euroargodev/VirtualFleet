# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from datetime import timedelta
import sys
import itertools
import cartopy.crs as ccrs
import cartopy.feature as cfeature
land_feature=cfeature.NaturalEarthFeature(category='physical',name='land',scale='50m',facecolor=[0.4,0.6,0.7])
pr1=ccrs.PlateCarree()
from glob import glob
from virtualargofleet import Velocity, FloatConfiguration, VirtualFleet
import cmocean

# %%
xr.open_dataset('/home/kbalem/Bureau/med_ens_daily_2024_glo031/med_cmems_mod_glo_phy-mnstd_my_0.25deg_P1D-m-20240101.nc')
# Out:
# <xarray.Dataset> Size: 29MB
# Dimensions:       (time: 1, latitude: 69, longitude: 173, depth: 75)
# Coordinates:
#   * time          (time) datetime64[ns] 8B 2024-01-01T12:00:00
#   * latitude      (latitude) float32 276B 30.0 30.25 30.5 ... 46.5 46.75 47.0
#   * longitude     (longitude) float32 692B -6.0 -5.75 -5.5 ... 36.5 36.75 37.0
#   * depth         (depth) float32 300B 0.5058 1.556 ... 5.698e+03 5.902e+03
# Data variables: (12/16)
#     mlotst_mean   (time, latitude, longitude) float32 48kB ...
#     mlotst_std    (time, latitude, longitude) float32 48kB ...
#     siconc_mean   (time, latitude, longitude) float32 48kB ...
#     siconc_std    (time, latitude, longitude) float32 48kB ...
#     sithick_mean  (time, latitude, longitude) float32 48kB ...
#     sithick_std   (time, latitude, longitude) float32 48kB ...
#     ...            ...
#     uo_mean       (time, depth, latitude, longitude) float32 4MB ...
#     uo_std        (time, depth, latitude, longitude) float32 4MB ...
#     vo_mean       (time, depth, latitude, longitude) float32 4MB ...
#     vo_std        (time, depth, latitude, longitude) float32 4MB ...
#     zos_mean      (time, latitude, longitude) float32 48kB ...
#     zos_std       (time, latitude, longitude) float32 48kB ...
# Attributes: (12/15)
#     product:                       GLOBAL_MULTIYEAR_PHY_ENS_001_031
#     producer:                      CMEMS - Global Monitoring and Forecasting ...
#     area:                          Global
#     quality_information_document:  http://marine.copernicus.eu/documents/QUID...
#     Conventions:                   CF-1.6
#     credit:                        E.U. Copernicus Marine Service Information...
#     ...                            ...
#     product_user_manual:           http://marine.copernicus.eu/documents/PUM/...
#     history:                       Thu Sep 10 09:29:27 2026: ncks -d longitud...
#     title:                         Daily mean fields for product GLOBAL_MULTI...
#     source:                        Copernicus Marine Service
#     institution:                   CMCC Foundation
#     NCO:                           netCDF Operators version 5.0.6 (Homepage =...

# %%
root = "/home/kbalem/Bureau/med_ens_daily_2024_glo031/*.nc"
filenames = {'U': root,
              'V': root}
variables = {'U':'uo_mean', 'V':'vo_mean'}
dimensions = {'time': 'time', 'depth':'depth', 'lat': 'latitude', 'lon': 'longitude'}
VELfield = Velocity(model='custom',
                    src=filenames,
                    variables=variables,
                    dimensions=dimensions,
                    time_periodic=timedelta(days=365))
# Out:
# /home/kbalem/miniforge3/envs/virtualfleet-deploy/lib/python3.11/site-packages/parcels/field.py:798: FieldSetWarning: allow_time_extrapolation and time_periodic cannot be used together. allow_time_extrapolation is set to False
#   return cls(
# /home/kbalem/miniforge3/envs/virtualfleet-deploy/lib/python3.11/site-packages/parcels/field.py:798: FieldSetWarning: allow_time_extrapolation and time_periodic cannot be used together. allow_time_extrapolation is set to False
#   return cls(

# %%
fieldset = VELfield.fieldset
fieldset.computeTimeChunk(fieldset.U.grid.time[0], 1.)
# Out:
# np.float64(86400.0)

# %%
fig=plt.figure(figsize=(16,5))
pr1=ccrs.PlateCarree()
pr2=ccrs.Mercator()
ax1 = fig.add_subplot(1, 3, 1, projection=pr2)
a=ax1.pcolormesh(fieldset.U.grid.lon,fieldset.U.grid.lat,fieldset.U.data[0,0,:-1,:-1],shading='flat',transform=pr1,vmin=-0.6,vmax=0.6,cmap=plt.get_cmap('RdBu'))
ax1.coastlines(resolution='110m',zorder=10)
plt.colorbar(a,location='top',shrink=0.6,label='U')
ga=ax1.gridlines(linestyle=':',draw_labels=True)
ga.top_labels, ga.right_labels = False, False
ax1 = fig.add_subplot(1, 3, 2, projection=pr2)
a=ax1.pcolormesh(fieldset.V.grid.lon,fieldset.V.grid.lat,fieldset.V.data[0,0,:-1,:-1],shading='flat',transform=pr1,vmin=-0.6,vmax=0.6,cmap=plt.get_cmap('RdBu'))
ax1.coastlines(resolution='110m',zorder=10)
plt.colorbar(a,location='top',shrink=0.6,label='V')
ga=ax1.gridlines(linestyle=':',draw_labels=True)
ga.top_labels, ga.right_labels = False, False
ax1 = fig.add_subplot(1, 3, 3, projection=pr2)
a=ax1.pcolormesh(fieldset.bathy.grid.lon,fieldset.bathy.grid.lat,fieldset.bathy.data[0,:-1,:-1],shading='flat',transform=pr1,cmap=cmocean.cm.deep,vmin=0)
ax1.coastlines(resolution='110m',zorder=10)
ga=ax1.gridlines(linestyle=':',draw_labels=True)
ga.top_labels, ga.right_labels = False, False
plt.colorbar(a,location='top',shrink=0.6,label='m')

# %%
from virtualargofleet.utilities import DeploymentPlan
d = DeploymentPlan()
d
# Out:
# <VirtualFleet.Deployment>
# Number of floats: 0
# Deployment plan:
# lon, lat, date, depth
# -------------------------
# -------------------------

# %%
d.from_region([3,5.5,37.6,38.5],'2024-03-01',1.5,method='grid',N=10)
# Out:
# <VirtualFleet.Deployment>
# Number of floats: 10
# Deployment plan:
# lon, lat, date, depth
# -------------------------
# 3.0, 37.6, 2024-03-01, 1.5
# 3.5, 37.6, 2024-03-01, 1.5
# 4.0, 37.6, 2024-03-01, 1.5
# 4.5, 37.6, 2024-03-01, 1.5
# 5.0, 37.6, 2024-03-01, 1.5
# 5.5, 37.6, 2024-03-01, 1.5
# 3.0, 38.5, 2024-03-01, 1.5
# 3.5, 38.5, 2024-03-01, 1.5
# 4.0, 38.5, 2024-03-01, 1.5
# 4.5, 38.5, 2024-03-01, 1.5
# -------------------------

# %%
d.plot()
# Out:
# <GeoAxes: >

# %%
cfg = FloatConfiguration('default')
cfg.update('parking_depth', 500)
cfg
# Out:
# <FloatConfiguration><default>
# - cycle_duration (Maximum length of float complete cycle): 240.0 [hours]
# - life_expectancy (Maximum number of completed cycle): 200 [cycle]
# - parking_depth (Drifting depth): 500.0 [m]
# - profile_depth (Maximum profile depth): 2000.0 [m]
# - vertical_speed (Vertical profiling speed): 0.09 [m/s]

# %%
VFleet = VirtualFleet(plan=d.plan, fieldset=VELfield, mission=cfg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 VFleet = VirtualFleet(plan=d.plan, fieldset=VELfield, mission=cfg)
#
# File ~/Bureau/VirtualFleet/virtualargofleet/virtualargofleet.py:75, in VirtualFleet.__init__(self, plan, fieldset, mission, isglobal, **kwargs)
#      73 for key in ['lat', 'lon', 'time']:
#      74     if key not in plan:
# ---> 75         raise ValueError("The 'plan' argument must have a '%s' key" % key)
#      76 default_plan = {'lat': None, 'lon': None, 'depth': None, 'time': None}
#      77 self.deployment_plan = {**default_plan, **plan}
#
# ValueError: The 'plan' argument must have a 'time' key
